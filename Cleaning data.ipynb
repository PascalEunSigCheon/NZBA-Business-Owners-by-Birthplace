# %% [markdown]
# # Cleaning Business owners by birthplace data
# In this Jupyter Notebook, we clane the data and prepare for PowerBI dashboard.

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import data

# %%
df = pd.read_excel('JOB- 11630 NZBA.xlsx', sheet_name = 'Table 1', skiprows = 10)
df.head()
# Out:
#                   Area                                         Occupation  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2  01 Northland Region  11 Chief Executives, General Managers and Legi...
# 3  01 Northland Region  11 Chief Executives, General Managers and Legi...
# 4  01 Northland Region  11 Chief Executives, General Managers and Legi...
#
#                   Birthplace     Unnamed: 3 Unnamed: 4  \
# 0                        NaN  Paid employee   Employer
# 1                        NaN            NaN        NaN
# 2              A New Zealand            720        930
# 3          A0101 New Zealand            720        930
# 4                 B Overseas            165        249
#
#                               Unnamed: 5            Unnamed: 6    Unnamed: 7  \
# 0  Self-employed and \nwithout employees  Unpaid family worker  Total stated
# 1                                    NaN                   NaN           NaN
# 2                                    354                    93          2103
# 3                                    354                    93          2103
# 4                                    135                    18           567
#
#                  Unnamed: 8 Unnamed: 9
# 0  Not elsewhere \nincluded      Total
# 1                       NaN        NaN
# 2                         0       2103
# 3                         0       2103
# 4                         0        567

# %% [markdown]
# Step 1. Have a look at the data head and modify accordingly

# %%
# Out:
#              2018 Census of Population and Dwellings Unnamed: 1 Unnamed: 2  \
# 0  Prepared for Pascal Eun Sig Cheon and Taz Muko...        NaN        NaN
# 1                           Job reference: JOB-11630        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  Refer to Data quality ratings for 2018 Census ...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# Clearly, there are initial rows we don't want. We get rid of these.

# %%
df.drop(range(0, 10))
# Out:
#                  2018 Census of Population and Dwellings  \
# 10                                                   NaN
# 11                                                   NaN
# 12                                   01 Northland Region
# 13                                   01 Northland Region
# 14                                   01 Northland Region
# ...                                                  ...
# 84809  the panel endorsed the overall methods Stats N...
# 84810  Its assessment of many other variables will be...
# 84811                                  (Link for report)
# 84812                                                NaN
# 84813                                   Source: Stats NZ
#
#                                               Unnamed: 1  \
# 10                                                   NaN
# 11                                                   NaN
# 12     11 Chief Executives, General Managers and Legi...
# 13     11 Chief Executives, General Managers and Legi...
# 14     11 Chief Executives, General Managers and Legi...
# ...                                                  ...
# 84809                                                NaN
# 84810                                                NaN
# 84811                                                NaN
# 84812                                                NaN
# 84813                                                NaN
#
#                       Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 10                           NaN  Paid employee   Employer
# 11                           NaN            NaN        NaN
# 12                 A New Zealand            720        930
# 13             A0101 New Zealand            720        930
# 14                    B Overseas            165        249
# ...                          ...            ...        ...
# 84809                        NaN            NaN        NaN
# 84810                        NaN            NaN        NaN
# 84811                        NaN            NaN        NaN
# 84812                        NaN            NaN        NaN
# 84813                        NaN            NaN        NaN
#
#                                   Unnamed: 5            Unnamed: 6  \
# 10     Self-employed and \nwithout employees  Unpaid family worker
# 11                                       NaN                   NaN
# 12                                       354                    93
# 13                                       354                    93
# 14                                       135                    18
# ...                                      ...                   ...
# 84809                                    NaN                   NaN
# 84810                                    NaN                   NaN
# 84811                                    NaN                   NaN
# 84812                                    NaN                   NaN
# 84813                                    NaN                   NaN
#
#          Unnamed: 7                Unnamed: 8 Unnamed: 9
# 10     Total stated  Not elsewhere \nincluded      Total
# 11              NaN                       NaN        NaN
# 12             2103                         0       2103
# 13             2103                         0       2103
# 14              567                         0        567
# ...             ...                       ...        ...
# 84809           NaN                       NaN        NaN
# 84810           NaN                       NaN        NaN
# 84811           NaN                       NaN        NaN
# 84812           NaN                       NaN        NaN
# 84813           NaN                       NaN        NaN
#
# [84804 rows x 10 columns]
